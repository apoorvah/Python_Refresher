# %%
# %pip install langchain-ollama langchain-openai

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage, AIMessage

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# %%
# model = ChatOllama(model="llama3.2:3b")
load_dotenv()
model = ChatOpenAI(model="gpt-4o-mini")

# %%
model
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x7e7baba546b0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7e7acad6bfe0>, root_client=<openai.OpenAI object at 0x7e7babe61dc0>, root_async_client=<openai.AsyncOpenAI object at 0x7e7baba33e30>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
response = model.invoke("Exaplin ML in 3 bullet points")

# %%
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# - **Definition**: Machine Learning (ML) is a subset of artificial intelligence that enables systems to learn from data, identify patterns, and make decisions with minimal human intervention.
#
# - **Types**: There are three primary types of ML: supervised learning (using labeled data to train models), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning optimal actions through trial and feedback).
#
# - **Applications**: ML is widely used in various fields, including healthcare (diagnosis prediction), finance (fraud detection), marketing (customer segmentation), and autonomous systems (self-driving cars).

# %%
response.content
# Out:
# '- **Definition**: Machine Learning (ML) is a subset of artificial intelligence that enables systems to learn from data, identify patterns, and make decisions with minimal human intervention.\n\n- **Types**: There are three primary types of ML: supervised learning (using labeled data to train models), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning optimal actions through trial and feedback).\n\n- **Applications**: ML is widely used in various fields, including healthcare (diagnosis prediction), finance (fraud detection), marketing (customer segmentation), and autonomous systems (self-driving cars).'

# %%
response.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 121,
#   'prompt_tokens': 16,
#   'total_tokens': 137,
#   'completion_tokens_details': {'accepted_prediction_tokens': 0,
#    'audio_tokens': 0,
#    'reasoning_tokens': 0,
#    'rejected_prediction_tokens': 0},
#   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#  'model_name': 'gpt-4o-mini-2024-07-18',
#  'system_fingerprint': 'fp_0542ea89f6',
#  'id': 'chatcmpl-DWxqvHULLmuS2UjKNBMMRhOOfdExx',
#  'service_tier': 'default',
#  'finish_reason': 'stop',
#  'logprobs': None}

# %%
response = model.invoke("Summarize the conversation so far")

# %%
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# You asked me to summarize our conversation, but there hasn't been any prior exchange for me to summarize. How can I assist you today?

# %%
model.invoke([
    HumanMessage("My name is Apoorva"),
    AIMessage("Hello Apoorva, how are you?"),
    HumanMessage("What is my name?")
])
# Out:
# AIMessage(content='Your name is Apoorva.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 35, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_77c1b30b18', 'id': 'chatcmpl-DWzTSUMHYG0L29pm8gTgxbS2njt8c', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--019daed8-4763-7a21-8538-a9cec6ac9e3d-0', usage_metadata={'input_tokens': 35, 'output_tokens': 7, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
