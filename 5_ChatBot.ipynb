# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

# %%
model = ChatOllama(
    model ="llama3.2:3b",
    temperature=0.6
)

# %%
sys_msg = SystemMessage("You are helpful assistant. You will answer every question with at most 2 bullet points")
history = []
history.append(sys_msg)
while True:
    user_input = input("Please enter your message(enter quit to exit)").strip()

    if user_input.lower() == "quit":
        print("Goodbye")
        break
    
    history.append(HumanMessage(user_input))
    response = model.invoke(history)
    history.append(response)
    response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Here's an explanation of Machine Learning (ML) in 2 bullet points:
#
# * **Definition:** Machine Learning is a subset of Artificial Intelligence (AI) that involves training algorithms to make predictions or decisions based on data, without being explicitly programmed.
# * **Key characteristics:**
# 	+ **Learning from data**: ML models learn patterns and relationships within data to improve their performance over time.
# 	+ **Improvement through experience**: As more data is added, the model's accuracy and effectiveness increase.
# ================================== Ai Message ==================================
#
# Here's an explanation of General Artificial Intelligence (GenAI) in 2 bullet points:
#
# * **Definition:** General Artificial Intelligence refers to a hypothetical AI system that possesses human-like intelligence, reasoning, and problem-solving abilities across a wide range of tasks and domains.
# * **Goals:**
# 	+ **Human-level understanding**: GenAI aims to create an AI system that can understand and replicate human thought processes, including common sense, intuition, and creativity.
# 	+ **Autonomy and flexibility**: GenAI seeks to develop an AI system that can adapt to new situations, learn from experience, and make decisions without being explicitly programmed.
# ================================== Ai Message ==================================
#
# Here's a brief description of India in 2 bullet points:
#
# * **Diverse culture and geography**: India is a vast and diverse country with a population of over 1.3 billion people, speaking over 22 official languages and practicing many more. It spans across several climate zones, from tropical to temperate.
# * **Economic and technological growth**: India has experienced rapid economic growth in recent decades, becoming the world's fifth-largest economy. The country is also a major hub for technology and innovation, with a thriving startup ecosystem and a growing presence of multinational companies.
# Goodbye

# %%
for message in history:
    message.pretty_print()
# Out:
# ================================ System Message ================================
#
# You are helpful assistant. You will answer every question with at most 2 bullet points
# ================================ Human Message =================================
#
# Explain ML
# ================================== Ai Message ==================================
#
# Here's an explanation of Machine Learning (ML) in 2 bullet points:
#
# * **Definition:** Machine Learning is a subset of Artificial Intelligence (AI) that involves training algorithms to make predictions or decisions based on data, without being explicitly programmed.
# * **Key characteristics:**
# 	+ **Learning from data**: ML models learn patterns and relationships within data to improve their performance over time.
# 	+ **Improvement through experience**: As more data is added, the model's accuracy and effectiveness increase.
# ================================ Human Message =================================
#
# What is GenAI
# ================================== Ai Message ==================================
#
# Here's an explanation of General Artificial Intelligence (GenAI) in 2 bullet points:
#
# * **Definition:** General Artificial Intelligence refers to a hypothetical AI system that possesses human-like intelligence, reasoning, and problem-solving abilities across a wide range of tasks and domains.
# * **Goals:**
# 	+ **Human-level understanding**: GenAI aims to create an AI system that can understand and replicate human thought processes, including common sense, intuition, and creativity.
# 	+ **Autonomy and flexibility**: GenAI seeks to develop an AI system that can adapt to new situations, learn from experience, and make decisions without being explicitly programmed.
# ================================ Human Message =================================
#
# Describe India
# ================================== Ai Message ==================================
#
# Here's a brief description of India in 2 bullet points:
#
# * **Diverse culture and geography**: India is a vast and diverse country with a population of over 1.3 billion people, speaking over 22 official languages and practicing many more. It spans across several climate zones, from tropical to temperate.
# * **Economic and technological growth**: India has experienced rapid economic growth in recent decades, becoming the world's fifth-largest economy. The country is also a major hub for technology and innovation, with a thriving startup ecosystem and a growing presence of multinational companies.
