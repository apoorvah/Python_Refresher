# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

model = ChatOllama(model="llama3.2:3b")

histories = {}

def get_history(session_id:str) -> ChatMessageHistory:
    if session_id not in histories:
        histories[session_id] = ChatMessageHistory()
    return histories[session_id]

chain = RunnableWithMessageHistory(model, get_history)

chain.invoke(HumanMessage("My name is apoorva"), 
             config={"configurable":{"session_id":"default"}})
# Out:
# AIMessage(content="Namaste Apoorva! It's nice to meet you. Is there anything I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'model': 'llama3.2:3b', 'created_at': '2026-04-21T09:06:51.490575243Z', 'done': True, 'done_reason': 'stop', 'total_duration': 726040819, 'load_duration': 238616246, 'prompt_eval_count': 31, 'prompt_eval_duration': 33603171, 'eval_count': 29, 'eval_duration': 388899980, 'logprobs': None, 'model_name': 'llama3.2:3b'}, id='run--019daf4a-d70a-7073-8007-8188e8920a6e-0', usage_metadata={'input_tokens': 31, 'output_tokens': 29, 'total_tokens': 60})

# %%
chain.invoke(HumanMessage("What is my name"), 
             config={"configurable":{"session_id":"new_session"}})
# Out:
# AIMessage(content="I don't have any information about your personal identity, so I won't be able to tell you your name. I'm a large language model, I don't retain any user data or personal information. Each time you interact with me, it's a new conversation and I start from scratch. If you'd like to share your name with me, I can certainly address you by that name in our conversation!", additional_kwargs={}, response_metadata={'model': 'llama3.2:3b', 'created_at': '2026-04-21T09:07:19.94858286Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1543083503, 'load_duration': 349521439, 'prompt_eval_count': 29, 'prompt_eval_duration': 33034717, 'eval_count': 83, 'eval_duration': 981141816, 'logprobs': None, 'model_name': 'llama3.2:3b'}, id='run--019daf4b-4301-7142-8707-0a0a5235c65b-0', usage_metadata={'input_tokens': 29, 'output_tokens': 83, 'total_tokens': 112})
