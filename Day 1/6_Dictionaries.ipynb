# %% [markdown]
# # Create dictionary
# * Empty
# * Different data types
# * Membership
# * len

# %% [markdown]
# # Accessing entries

# %% [markdown]
# # Modifying values

# %% [markdown]
# # Adding and removing entries

# %% [markdown]
# # Dictionary functions
#
# * retrieve all keys
# * retrieve all keys
# * retrieve all key-value pairs
# * get funtion
