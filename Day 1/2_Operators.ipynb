# %%
x = 10
y = 3

# %% [markdown]
# # Artihmetic
# * Normal arithmetic
# * Shorthand +=

# %% [markdown]
# # Comparison

# %% [markdown]
# # Logical

# %% [markdown]
# # Object identity
#
# `is` operator
