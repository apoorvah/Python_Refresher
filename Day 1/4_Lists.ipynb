# %% [markdown]
# # Create list
#
# *  Empty
# *  Single element
# *  Different data types
# *  Membership
# *  Length

# %% [markdown]
# # Indexing
#
# * Positive
# * Negative

# %% [markdown]
# # Slicing

# %% [markdown]
# # List functions
#
# * Append
# * Remove
