# %% [markdown]
# # Create set
# * Empty set
# * Single element set
# * Different data types
# * Membership
# * Len

# %%
my_set = {10, "Python", 3.14, "AI", 42, "Data", 7.89}
print(my_set)
# Out:
# {'AI', 3.14, 42, 7.89, 'Data', 10, 'Python'}

# %% [markdown]
# # Adding and removing from a set

# %% [markdown]
# # Adding a duplicate entry into set

# %% [markdown]
# #Set operations
# * union
# * intersection
# * difference operations

# %% [markdown]
# # Remove duplicates from the list
