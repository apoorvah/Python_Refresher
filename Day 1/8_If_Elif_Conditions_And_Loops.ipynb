# %% [markdown]
# # If..Elif..Else
# Given a score, categorize it as:
# * Distinction if it is 75 or above
# * Pass if it is between 50 and 74
# * Fail if it is below 50
#
# *Optoinal:* Try ternary conditional operator
#
# value_if_true `if` condition `else` value_if_false

# %% [markdown]
# # For loop
# * Loop over list
# * Loop over index using range
# * Loop over index + value using list
#
# **Exercise:** Given a list of numbers, print a list of only the odd numbers
# *Optional* : Try list comprehension

# %% [markdown]
# # While loop
# * Loop till condition is true
# * Infinite loop
#
# **Exercise:** Repeatedly ask the user to enter a value. Store the user inputs in an appropriate data structure. Stop when the user enters "quit"

# %% [markdown]
# # Break and continue

# %% [markdown]
# # Optional:
# * Try nested ifs, loops
# * Try match .. case
