# %% [markdown]
# # `f` strings

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Number Formatting

# %% [markdown]
# # Reference
#
# https://www.w3schools.com/python/python_string_formatting.asp
