# %% [markdown]
# # Hello World

# %% [markdown]
# # Indentation

# %% [markdown]
# # Comments
#
#
#
# *   Single line
# *   Multi line

# %% [markdown]
# # Variables
#
#
#
# *   Naming convention
# *   Data type

# %% [markdown]
# # Input/Output
