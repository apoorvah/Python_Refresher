# %%
#%pip install ollama

# %%
import ollama

# %%
response = ollama.generate(model="llama3.2:3b", 
                prompt="Summarize GenAI in one line")

# %%
response
# Out:
# GenerateResponse(model='llama3.2:3b', created_at='2026-04-20T09:56:57.742944741Z', done=True, done_reason='stop', total_duration=898937985, load_duration=253632459, prompt_eval_count=33, prompt_eval_duration=17804200, eval_count=41, eval_duration=529699658, response='GenAI refers to a subfield of artificial intelligence (AI) that focuses on developing general-purpose, multimodal AI models capable of reasoning, learning, and understanding human language and behavior across various domains.', thinking=None, context=[128006, 9125, 128007, 271, 38766, 1303, 33025, 2696, 25, 6790, 220, 2366, 18, 271, 128009, 128006, 882, 128007, 271, 9370, 5730, 553, 9500, 15836, 304, 832, 1584, 128009, 128006, 78191, 128007, 271, 10172, 15836, 19813, 311, 264, 1207, 2630, 315, 21075, 11478, 320, 15836, 8, 430, 24400, 389, 11469, 4689, 59338, 11, 80149, 58697, 15592, 4211, 13171, 315, 33811, 11, 6975, 11, 323, 8830, 3823, 4221, 323, 7865, 4028, 5370, 31576, 13], logprobs=None)

# %%
response.response
# Out:
# 'GenAI refers to a subfield of artificial intelligence (AI) that focuses on developing general-purpose, multimodal AI models capable of reasoning, learning, and understanding human language and behavior across various domains.'

# %%
chat_response = ollama.chat(model = "llama3.2:3b",
            messages=[
               {"role": "user", "content": "Hi, I am Apoorva"}, 
               {"role": "assistant", "content": "Hi, Apoorva how are you?"},
               {"role": "user", "content": "What is my name?"}
            ])
chat_response
# Out:
# ChatResponse(model='llama3.2:3b', created_at='2026-04-20T10:08:52.015455454Z', done=True, done_reason='stop', total_duration=466379474, load_duration=268702971, prompt_eval_count=56, prompt_eval_duration=49081966, eval_count=8, eval_duration=125456775, message=Message(role='assistant', content='Your name is Apoorva!', thinking=None, images=None, tool_name=None, tool_calls=None), logprobs=None)

# %%
chat_response.message.content
# Out:
# 'Your name is Apoorva!'
