# %% [markdown]
# # Income Dataset
#
# https://www.kaggle.com/datasets/priyamchoksi/adult-census-income-dataset/data

# %% [markdown]
# ### Fix the code

# %%
print(pd.__version__)
# Out:
# 2.0.3

# %% [markdown]
# ### Create a DataFrame of Income Dataset
#
# 1. Head over to https://www.kaggle.com/datasets/priyamchoksi/adult-census-income-dataset/data and download the data
#
# 2. Load data to DataFrame
#
# 3. Display the first 8 entries
#
# 4. Display the last 8 entries
#
# 5. Display 8 random entries
#
# 6. Display the number of rows and number of columns in the data.
#
# 7. Display the data types of all the columns
#
# 8. Display the column names

# %% [markdown]
# ### From the Income DataFrame, extract the column "race". Display the outputs for the following?
# 1. Is the extracted data a Series or Dataframe. Use appopriate function to check this?
# 2. Display the number of unique values
# 3. Display the unique values

# %% [markdown]
# ### Only for numerical data, print the summary statistics. For each of these column, check if the mean value is at the center

# %% [markdown]
# ### Only for object data, print the summary statistics.

# %% [markdown]
# ### Print overall summary statistics

# %% [markdown]
# ###Display column $\texttt{marital.status}$

# %% [markdown]
# ###For the columns $\texttt{marital.status, race and sex}$ display the summary statistics

# %% [markdown]
# ### What are the unique values present in $\texttt{education}$

# %% [markdown]
# ### Display all rows with "Private" $\texttt{wrkclass}$

# %% [markdown]
# ###Display all rows with "Private" $\texttt{wrkclass}$ and income > 50k

# %% [markdown]
# ### Display the education and occupation corresponding to max capital gain

# %% [markdown]
# ### Display the income by hours-per-week
